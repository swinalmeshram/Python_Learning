# %% [markdown]
# # python class

# %% [markdown]
# wonderful start for the day

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
age = 18
age
# Out:
# 18

# %%
# comment
# line 1
# line 2
"""
python is 
a good language
"""
# Out:
# '\npython is \na good language\n'

# %%
print("python is a good programming language")
# Out:
# python is a good programming language

# %%
print('pthon is a good prgramming language')
# Out:
# pthon is a good prgramming language

# %%
f_name = "Swinal"
l_name = "Meshram"
print("name: ",f_name,l_name)
# Out:
# name:  Swinal Meshram

# %%
type(f_name)
# Out:
# str

# %%
f = 5.4
print(f)
type(f)
# Out:
# 5.4
# float

# %%
marital_status = True
print(marital_status)
print(type(marital_status))
# Out:
# True
# <class 'bool'>

# %%
emp_name = "swinal meshram"
emp_id = 100
dept = "CSE"
email = "swinalmesh3@gmail.com"
age = 26
contact = 9001187381
height = 5.10
weight = 72
salary = 5000
city = "chennai"
print("employee name is   : ", emp_name, type(emp_name))
print("employee id is     : ", emp_id, type(emp_id))
print("employee dept is   : ", dept, type(dept))
print("employee email is   : ", email, type(email))
print("employee age is    : ", age, type(age))
print("employee contact is : ", contact, type(contact))
print("employee height is : ",height, type(height))
print("employee weight is : ", weight, type(weight))
print("employee salary is : ", salary, type(salary))
print("employee city is : ", city, type(city))
# Out:
# employee name is   :  swinal meshram <class 'str'>
# employee id is     :  100 <class 'int'>
# employee dept is   :  CSE <class 'str'>
# employee email is   :  swinalmesh3@gmail.com <class 'str'>
# employee age is    :  26 <class 'int'>
# employee contact is :  9001187381 <class 'int'>
# employee height is :  5.1 <class 'float'>
# employee weight is :  72 <class 'int'>
# employee salary is :  5000 <class 'int'>
# employee city is :  chennai <class 'str'>

# %%
name, age, city = 'Swinal', 10, 'Chennai'
print(name, age, city)
# Out:
# Swinal 10 Chennai

# %%
x =y=z = 10
print(x,y,z)
# Out:
# 10 10 10

# %%
a=4
b=0.5
print(a,type(a),b,type(b))
# Out:
# 4 <class 'int'> 0.5 <class 'float'>

# %%
print(a+b,type(a+b))
# Out:
# 4.5 <class 'float'>

# %%
a = '10'
a = int(a)
a= float(a)
type(a)
a
# Out:
# 10.0

# %%
a , b = 50.0, '10'
c = int(a+int(b))
print(c,type(c))
# Out:
# 60 <class 'int'>

# %%
a = 'cat' + ' dog' + '1'
a
# Out:
# 'cat dog1'

# %%
a = 'great' 
b= ' learning'
c = a + b
c
# Out:
# 'great learning'

# %%
a = 'great learning '  * 10
print(a)
print('great learniong\n' * 10)
# Out:
# great learning great learning great learning great learning great learning great learning great learning great learning great learning great learning
# great learniong
# great learniong
# great learniong
# great learniong
# great learniong
# great learniong
# great learniong
# great learniong
# great learniong
# great learniong

# %%
a = 27
b = 2
print(a/b)
print(a//b)
print(a%b)
# Out:
# 13.5
# 13
# 1

# %%
x = 10
out = x*x
print('squared value of x : ', out)
out2= x**3
print('cube value of x = ', out2)
# Out:
# squared value of x :  100
# cube value of x =  1000

# %%
a = 2
b=3
c=2
d =(a **b) **c
d
# Out:
# 64

# %% [markdown]
# # 4 errors
# . type errors
# . syntax error
# . value error
# . ident error

# %%
name = input("enter your name")
print('Welcome to the course: ', name)
# Out:
# enter your nameswinal
# Welcome to the course:  swinal

# %%
a = int(input("Enter the value : "))
b = int(input("Enter the value : "))
c = a + b
print("Addition = ",c)
# Out:
# Enter the value : 3
# Enter the value : 4
# Addition =  7

# %%
a = int(input("Enter the value : "))
b = float(input("Enter the value : "))
c = a + b
print("Addition = ",c)
# Out:
# Enter the value : 3
# Enter the value : 5.7
# Addition =  8.7

# %%
a= 50
b = 40
print(a>b)
print(a<b)
print(a==b)
# Out:
# True
# False
# False

# %%
age = 20
gender = 'M'
age>=18 or gender == 'F'
# Out:
# True

# %%
a = 10
b = 1
a+=b
a
# Out:
# 11

# %%
lis = ['a', 'b', 'c']
'#'.join(lis)
# Out:
# 'a#b#c'

# %%
print('a is {} and b is {}'.format(a,b))
# Out:
# a is 11 and b is 1

# %%
print('a is %d and b is %d'%(a,b))
# Out:
# a is 11 and b is 1

# %%
print('a is %.2f and b is %.3f'%(a,b))
# Out:
# a is 11.00 and b is 1.000

# %%
nm = 'great learning'
len(nm)
# Out:
# 14

# %%
nm.replace('g','G')
# Out:
# 'Great learninG'

# %%
nm = ' great '
nm.strip()
# Out:
# 'great'

# %%
nm.upper()
# Out:
# ' GREAT '

# %%
nm.title()
# Out:
# ' Great '

# %%
nb = 'great learning python course'
nb.split()
# Out:
# ['great', 'learning', 'python', 'course']

# %%
a = 'malylam'
a[1:4]
# Out:
# 'aly'

# %%
a[::-1]
# Out:
# 'malylam'

# %%
b= a[::-1]
b
a==b
# Out:
# True
